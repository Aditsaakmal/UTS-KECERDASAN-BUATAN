# %%
# Data

company_detail_list = [
      {
          'name': 'Company 1',
          'domain': 'Retail',
          'country': 'United States'
      },
      {
          'name': 'Company 2',
          'domain': 'Technology',
          'country': 'United Kingdom'
      },
      {
          'name': 'Company 3',
          'domain': 'Healthcare',
          'country': 'United States'
      }
  ]

employee_detail_list = [
     {
          'name': 'EMP-0001',
          'first_name': 'John',
          'last_name': 'Doe',
          'full_name': 'John Doe',
          'company': 'Company 1',
          'nationality': 'Australia'
      },
      {
          'name': 'EMP-0002',
          'first_name': 'Tom',
          'last_name': 'Smith',
          'full_name': 'Tom Smith',
          'company': 'Company 2',
          'nationality': 'United States'
      },
      {
          'name': 'EMP-0003',
          'first_name': 'Andrew',
          'last_name': 'Sebastian',
          'full_name': 'Andrew Sebastian',
          'company': 'Company 3',
          'nationality': 'United States'
      },
      {
          'name': 'EMP-0005',
          'first_name': 'Ying Han',
          'last_name': 'Tan',
          'full_name': 'Ying Han Tan',
          'company': 'Company 1',
          'nationality': 'Australia'
      },
      {
          'name': 'EMP-0015',
          'first_name': 'Kenneth',
          'last_name': 'Ng',
          'full_name': 'Kenneth Ng',
          'company': 'Company 3',
          'nationality': 'United States'
      },
      {
          'name': 'EMP-0018',
          'first_name': 'Rubby',
          'last_name': 'Lee',
          'full_name': 'Rubby Lee',
          'company': 'Company 2',
          'nationality': 'Hong Kong'
      },
     {
          'name': 'EMP-0017',
          'first_name': 'Robert',
          'last_name': 'White',
          'full_name': 'Robert White',
          'company': 'Company 1',
          'nationality': 'United Kingdom'
      }
  ]

# %%
def reverse_company_names(company_list):
    # Mengurutkan daftar nama perusahaan secara terbalik
    return [{"name": company["name"]} for company in sorted(company_list, key=lambda x: x["name"], reverse=True)]

reverse_company_names(company_detail_list)
# Out:
# [{'name': 'Company 3'}, {'name': 'Company 2'}, {'name': 'Company 1'}]

# %%
def print_company_domains(company_list):
    for company in company_list:
        print(f"{company['name']}: {company['domain']} ({company['country']})")

print_company_domains(company_detail_list)
# Out:
# Company 1: Retail (United States)
# Company 2: Technology (United Kingdom)
# Company 3: Healthcare (United States)

# %%
from collections import defaultdict

# Daftar nama perusahaan
company_detail_list = [
    {
        'name': 'Company 1',
        'domain': 'Retail',
        'country': 'United States'
    },
    {
        'name': 'Company 2',
        'domain': 'Technology',
        'country': 'United Kingdom'
    },
    {
        'name': 'Company 3',
        'domain': 'Healthcare',
        'country': 'United States'
    }
]

# Daftar nama karyawan
employee_detail_list = [
    {
        'name': 'EMP-0001',
        'first_name': 'John',
        'last_name': 'Doe',
        'full_name': 'John Doe',
        'company': 'Company 1',
        'nationality': 'Australia'
    },
    {
        'name': 'EMP-0002',
        'first_name': 'Tom',
        'last_name': 'Smith',
        'full_name': 'Tom Smith',
        'company': 'Company 2',
        'nationality': 'United States'
    },
    {
        'name': 'EMP-0003',
        'first_name': 'Andrew',
        'last_name': 'Sebastian',
        'full_name': 'Andrew Sebastian',
        'company': 'Company 3',
        'nationality': 'United States'
    },
    {
        'name': 'EMP-0005',
        'first_name': 'Ying Han',
        'last_name': 'Tan',
        'full_name': 'Ying Han Tan',
        'company': 'Company 1',
        'nationality': 'Australia'
    },
    {
        'name': 'EMP-0015',
        'first_name': 'Kenneth',
        'last_name': 'Ng',
        'full_name': 'Kenneth Ng',
        'company': 'Company 3',
        'nationality': 'United States'
    },
    {
        'name': 'EMP-0018',
        'first_name': 'Rubby',
        'last_name': 'Lee',
        'full_name': 'Rubby Lee',
        'company': 'Company 2',
        'nationality': 'Hong Kong'
    },
    {
        'name': 'EMP-0017',
        'first_name': 'Robert',
        'last_name': 'White',
        'full_name': 'Robert White',
        'company': 'Company 1',
        'nationality': 'United Kingdom'
    }
]

# mencantumkan semua pekerjaan karyawan berdasarkan domain perusahaan
def list_employees_by_domain(company_list, employee_list):
    # mapping perusahaan dan domain
    domain_mapping = {company["name"]: company["domain"] for company in company_list}
    # dictionary untuk menampung hasil berdasarkan domain
    domain_employees = defaultdict(list)

    # Menambahkan nama karyawan ke dalam domain 
    for employee in employee_list:
        domain = domain_mapping.get(employee["company"])
        if domain:  
            domain_employees[domain].append(employee["full_name"])
    
    return dict(domain_employees)

# fungsi dan cetak hasilnya
result = list_employees_by_domain(company_detail_list, employee_detail_list)
print(result)
# Out:
# {'Retail': ['John Doe', 'Ying Han Tan', 'Robert White'], 'Technology': ['Tom Smith', 'Rubby Lee'], 'Healthcare': ['Andrew Sebastian', 'Kenneth Ng']}

# %%
def employees_with_company_country(company_list, employee_list):
    # mapping antara perusahaan dan negara
    country_mapping = {company["name"]: company["country"] for company in company_list}
    # Buat daftar hasil berdasarkan negara perusahaan
    result = []
    for employee in employee_list:
        result.append({
            "full_name": employee["full_name"],
            "company": employee["company"],
            "country": country_mapping.get(employee["company"])
        })
    return result

employees_with_company_country(company_detail_list, employee_detail_list)
# Out:
# [{'full_name': 'John Doe', 'company': 'Company 1', 'country': 'United States'},
#  {'full_name': 'Tom Smith',
#   'company': 'Company 2',
#   'country': 'United Kingdom'},
#  {'full_name': 'Andrew Sebastian',
#   'company': 'Company 3',
#   'country': 'United States'},
#  {'full_name': 'Ying Han Tan',
#   'company': 'Company 1',
#   'country': 'United States'},
#  {'full_name': 'Kenneth Ng',
#   'company': 'Company 3',
#   'country': 'United States'},
#  {'full_name': 'Rubby Lee',
#   'company': 'Company 2',
#   'country': 'United Kingdom'},
#  {'full_name': 'Robert White',
#   'company': 'Company 1',
#   'country': 'United States'}]

# %%
from collections import Counter

def company_employee_nationalities(company_list, employee_list):
    # Buat dictionary untuk menyimpan hasil
    result = []
    for company in company_list:
        # Filter karyawan berdasarkan perusahaan
        employees = [emp for emp in employee_list if emp["company"] == company["name"]]
        # Hitung jumlah kewarganegaraan
        nationality_count = Counter(emp["nationality"] for emp in employees)
        result.append({
            "company": company["name"],
            "employee_nationality": dict(nationality_count)
        })
    return result

company_employee_nationalities(company_detail_list, employee_detail_list)
# Out:
# [{'company': 'Company 1',
#   'employee_nationality': {'Australia': 2, 'United Kingdom': 1}},
#  {'company': 'Company 2',
#   'employee_nationality': {'United States': 1, 'Hong Kong': 1}},
#  {'company': 'Company 3', 'employee_nationality': {'United States': 2}}]
